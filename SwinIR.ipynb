# %% [markdown]
# # Wrapper for SwinIR
#
# > I have taken the code from [__Wrapper for SwinIR__](https://github.com/Lin-Sinorodin/SwinIR_wrapper) repository. This wrapper based on the official PyTorch implementation of [SwinIR: Image Restoration Using Shifted Window Transformer](https://arxiv.org/abs/2108.10257).

# %%
#@title Imports and Utils { display-mode: "form" }

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# %config InlineBackend.rc = {'figure.figsize': (10.0, 10.0)}

# !git clone -qq https://github.com/Lin-Sinorodin/SwinIR_wrapper.git
# !pip install -qq timm
from SwinIR_wrapper.SwinIR_wrapper import SwinIR_SR

import cv2
import torch
import urllib.request
import matplotlib.pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available():
    print(f'Using GPU: {torch.cuda.get_device_properties(0).name}')
else:
    print('Using CPU. Concider using GPU for faster inference.')

def compare_sr_with_original(img_lq, img_hq):
    plt.figure()

    plt.subplot(1, 2, 1)
    plt.imshow(img_lq[::,::,::-1])
    plt.title(f'Original - {img_lq.shape}')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(img_hq[::,::,::-1])
    plt.title(f'Super Resolution - {img_hq.shape}')
    plt.axis('off')

    plt.tight_layout()
    plt.show()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 38.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.6 MB/s eta 0:00:00
# /content/SwinIR_wrapper/SwinIR_wrapper/SwinIR.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# Using GPU: Tesla T4

# %%
import cv2

video_path = '/content/drive/MyDrive/test.mp4'
output_folder = r'/content/drive/MyDrive/frames/'

cap = cv2.VideoCapture(video_path)
frame_count = 0

if not cap.isOpened():
    print("Error: Video file not found or cannot be opened.")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_count += 1
        frame_filename = f"{output_folder}frame_{frame_count:04d}.jpg"
        print(frame_filename)
        cv2.imwrite(frame_filename, frame)
        if not cv2.imwrite(frame_filename, frame):
          raise Exception("Could not write image")

    cap.release()
    print(f"Extracted {frame_count} frames.")
# Out:
# /content/drive/MyDrive/frames/frame_0001.jpg
# /content/drive/MyDrive/frames/frame_0002.jpg
# /content/drive/MyDrive/frames/frame_0003.jpg
# /content/drive/MyDrive/frames/frame_0004.jpg
# /content/drive/MyDrive/frames/frame_0005.jpg
# /content/drive/MyDrive/frames/frame_0006.jpg
# /content/drive/MyDrive/frames/frame_0007.jpg
# /content/drive/MyDrive/frames/frame_0008.jpg
# /content/drive/MyDrive/frames/frame_0009.jpg
# /content/drive/MyDrive/frames/frame_0010.jpg
# /content/drive/MyDrive/frames/frame_0011.jpg
# /content/drive/MyDrive/frames/frame_0012.jpg
# /content/drive/MyDrive/frames/frame_0013.jpg
# /content/drive/MyDrive/frames/frame_0014.jpg
# /content/drive/MyDrive/frames/frame_0015.jpg
# /content/drive/MyDrive/frames/frame_0016.jpg
# /content/drive/MyDrive/frames/frame_0017.jpg
# /content/drive/MyDrive/frames/frame_0018.jpg
# /content/drive/MyDrive/frames/frame_0019.jpg
# /content/drive/MyDrive/frames/frame_0020.jpg
# /content/drive/MyDrive/frames/frame_0021.jpg
# /content/drive/MyDrive/frames/frame_0022.jpg
# /content/drive/MyDrive/frames/frame_0023.jpg
# /content/drive/MyDrive/frames/frame_0024.jpg
# /content/drive/MyDrive/frames/frame_0025.jpg
# /content/drive/MyDrive/frames/frame_0026.jpg
# /content/drive/MyDrive/frames/frame_0027.jpg
# /content/drive/MyDrive/frames/frame_0028.jpg
# /content/drive/MyDrive/frames/frame_0029.jpg
# /content/drive/MyDrive/frames/frame_0030.jpg
# /content/drive/MyDrive/frames/frame_0031.jpg
# /content/drive/MyDrive/frames/frame_0032.jpg
# /content/drive/MyDrive/frames/frame_0033.jpg
# /content/drive/MyDrive/frames/frame_0034.jpg
# /content/drive/MyDrive/frames/frame_0035.jpg
# /content/drive/MyDrive/frames/frame_0036.jpg
# /content/drive/MyDrive/frames/frame_0037.jpg
# /content/drive/MyDrive/frames/frame_0038.jpg
# /content/drive/MyDrive/frames/frame_0039.jpg
# /content/drive/MyDrive/frames/frame_0040.jpg
# /content/drive/MyDrive/frames/frame_0041.jpg
# /content/drive/MyDrive/frames/frame_0042.jpg
# /content/drive/MyDrive/frames/frame_0043.jpg
# /content/drive/MyDrive/frames/frame_0044.jpg
# /content/drive/MyDrive/frames/frame_0045.jpg
# /content/drive/MyDrive/frames/frame_0046.jpg
# /content/drive/MyDrive/frames/frame_0047.jpg
# /content/drive/MyDrive/frames/frame_0048.jpg
# /content/drive/MyDrive/frames/frame_0049.jpg
# /content/drive/MyDrive/frames/frame_0050.jpg
# /content/drive/MyDrive/frames/frame_0051.jpg
# /content/drive/MyDrive/frames/frame_0052.jpg
# /content/drive/MyDrive/frames/frame_0053.jpg
# /content/drive/MyDrive/frames/frame_0054.jpg
# /content/drive/MyDrive/frames/frame_0055.jpg
# /content/drive/MyDrive/frames/frame_0056.jpg
# /content/drive/MyDrive/frames/frame_0057.jpg
# /content/drive/MyDrive/frames/frame_0058.jpg
# /content/drive/MyDrive/frames/frame_0059.jpg
# /content/drive/MyDrive/frames/frame_0060.jpg
# /content/drive/MyDrive/frames/frame_0061.jpg
# /content/drive/MyDrive/frames/frame_0062.jpg
# /content/drive/MyDrive/frames/frame_0063.jpg
# /content/drive/MyDrive/frames/frame_0064.jpg
# /content/drive/MyDrive/frames/frame_0065.jpg
# /content/drive/MyDrive/frames/frame_0066.jpg
# /content/drive/MyDrive/frames/frame_0067.jpg
# /content/drive/MyDrive/frames/frame_0068.jpg
# /content/drive/MyDrive/frames/frame_0069.jpg
# /content/drive/MyDrive/frames/frame_0070.jpg
# /content/drive/MyDrive/frames/frame_0071.jpg
# /content/drive/MyDrive/frames/frame_0072.jpg
# /content/drive/MyDrive/frames/frame_0073.jpg
# /content/drive/MyDrive/frames/frame_0074.jpg
# /content/drive/MyDrive/frames/frame_0075.jpg
# /content/drive/MyDrive/frames/frame_0076.jpg
# /content/drive/MyDrive/frames/frame_0077.jpg
# /content/drive/MyDrive/frames/frame_0078.jpg
# /content/drive/MyDrive/frames/frame_0079.jpg
# /content/drive/MyDrive/frames/frame_0080.jpg
# /content/drive/MyDrive/frames/frame_0081.jpg
# /content/drive/MyDrive/frames/frame_0082.jpg
# /content/drive/MyDrive/frames/frame_0083.jpg
# /content/drive/MyDrive/frames/frame_0084.jpg
# /content/drive/MyDrive/frames/frame_0085.jpg
# /content/drive/MyDrive/frames/frame_0086.jpg
# /content/drive/MyDrive/frames/frame_0087.jpg
# /content/drive/MyDrive/frames/frame_0088.jpg
# /content/drive/MyDrive/frames/frame_0089.jpg
# /content/drive/MyDrive/frames/frame_0090.jpg
# /content/drive/MyDrive/frames/frame_0091.jpg
# /content/drive/MyDrive/frames/frame_0092.jpg
# /content/drive/MyDrive/frames/frame_0093.jpg
# /content/drive/MyDrive/frames/frame_0094.jpg
# /content/drive/MyDrive/frames/frame_0095.jpg
# /content/drive/MyDrive/frames/frame_0096.jpg
# /content/drive/MyDrive/frames/frame_0097.jpg
# /content/drive/MyDrive/frames/frame_0098.jpg
# /content/drive/MyDrive/frames/frame_0099.jpg
# /content/drive/MyDrive/frames/frame_0100.jpg
# /content/drive/MyDrive/frames/frame_0101.jpg
# /content/drive/MyDrive/frames/frame_0102.jpg
# /content/drive/MyDrive/frames/frame_0103.jpg
# /content/drive/MyDrive/frames/frame_0104.jpg
# /content/drive/MyDrive/frames/frame_0105.jpg
# /content/drive/MyDrive/frames/frame_0106.jpg
# /content/drive/MyDrive/frames/frame_0107.jpg
# /content/drive/MyDrive/frames/frame_0108.jpg
# /content/drive/MyDrive/frames/frame_0109.jpg
# /content/drive/MyDrive/frames/frame_0110.jpg
# /content/drive/MyDrive/frames/frame_0111.jpg
# /content/drive/MyDrive/frames/frame_0112.jpg
# /content/drive/MyDrive/frames/frame_0113.jpg
# /content/drive/MyDrive/frames/frame_0114.jpg
# /content/drive/MyDrive/frames/frame_0115.jpg
# /content/drive/MyDrive/frames/frame_0116.jpg
# /content/drive/MyDrive/frames/frame_0117.jpg
# /content/drive/MyDrive/frames/frame_0118.jpg
# /content/drive/MyDrive/frames/frame_0119.jpg
# /content/drive/MyDrive/frames/frame_0120.jpg
# /content/drive/MyDrive/frames/frame_0121.jpg
# /content/drive/MyDrive/frames/frame_0122.jpg
# /content/drive/MyDrive/frames/frame_0123.jpg
# /content/drive/MyDrive/frames/frame_0124.jpg
# /content/drive/MyDrive/frames/frame_0125.jpg
# /content/drive/MyDrive/frames/frame_0126.jpg
# /content/drive/MyDrive/frames/frame_0127.jpg
# /content/drive/MyDrive/frames/frame_0128.jpg
# /content/drive/MyDrive/frames/frame_0129.jpg
# /content/drive/MyDrive/frames/frame_0130.jpg
# /content/drive/MyDrive/frames/frame_0131.jpg
# /content/drive/MyDrive/frames/frame_0132.jpg
# /content/drive/MyDrive/frames/frame_0133.jpg
# /content/drive/MyDrive/frames/frame_0134.jpg
# /content/drive/MyDrive/frames/frame_0135.jpg
# /content/drive/MyDrive/frames/frame_0136.jpg
# /content/drive/MyDrive/frames/frame_0137.jpg
# /content/drive/MyDrive/frames/frame_0138.jpg
# /content/drive/MyDrive/frames/frame_0139.jpg
# /content/drive/MyDrive/frames/frame_0140.jpg
# /content/drive/MyDrive/frames/frame_0141.jpg
# /content/drive/MyDrive/frames/frame_0142.jpg
# /content/drive/MyDrive/frames/frame_0143.jpg
# /content/drive/MyDrive/frames/frame_0144.jpg
# /content/drive/MyDrive/frames/frame_0145.jpg
# /content/drive/MyDrive/frames/frame_0146.jpg
# /content/drive/MyDrive/frames/frame_0147.jpg
# /content/drive/MyDrive/frames/frame_0148.jpg
# /content/drive/MyDrive/frames/frame_0149.jpg
# /content/drive/MyDrive/frames/frame_0150.jpg
# /content/drive/MyDrive/frames/frame_0151.jpg
# /content/drive/MyDrive/frames/frame_0152.jpg
# /content/drive/MyDrive/frames/frame_0153.jpg
# /content/drive/MyDrive/frames/frame_0154.jpg
# /content/drive/MyDrive/frames/frame_0155.jpg
# /content/drive/MyDrive/frames/frame_0156.jpg
# /content/drive/MyDrive/frames/frame_0157.jpg
# /content/drive/MyDrive/frames/frame_0158.jpg
# /content/drive/MyDrive/frames/frame_0159.jpg
# /content/drive/MyDrive/frames/frame_0160.jpg
# /content/drive/MyDrive/frames/frame_0161.jpg
# /content/drive/MyDrive/frames/frame_0162.jpg
# /content/drive/MyDrive/frames/frame_0163.jpg
# /content/drive/MyDrive/frames/frame_0164.jpg
# /content/drive/MyDrive/frames/frame_0165.jpg
# /content/drive/MyDrive/frames/frame_0166.jpg
# /content/drive/MyDrive/frames/frame_0167.jpg
# /content/drive/MyDrive/frames/frame_0168.jpg
# /content/drive/MyDrive/frames/frame_0169.jpg
# /content/drive/MyDrive/frames/frame_0170.jpg
# /content/drive/MyDrive/frames/frame_0171.jpg
# /content/drive/MyDrive/frames/frame_0172.jpg
# /content/drive/MyDrive/frames/frame_0173.jpg
# /content/drive/MyDrive/frames/frame_0174.jpg
# /content/drive/MyDrive/frames/frame_0175.jpg
# /content/drive/MyDrive/frames/frame_0176.jpg
# /content/drive/MyDrive/frames/frame_0177.jpg
# /content/drive/MyDrive/frames/frame_0178.jpg
# /content/drive/MyDrive/frames/frame_0179.jpg
# /content/drive/MyDrive/frames/frame_0180.jpg
# /content/drive/MyDrive/frames/frame_0181.jpg
# /content/drive/MyDrive/frames/frame_0182.jpg
# /content/drive/MyDrive/frames/frame_0183.jpg
# /content/drive/MyDrive/frames/frame_0184.jpg
# /content/drive/MyDrive/frames/frame_0185.jpg
# /content/drive/MyDrive/frames/frame_0186.jpg
# /content/drive/MyDrive/frames/frame_0187.jpg
# /content/drive/MyDrive/frames/frame_0188.jpg
# /content/drive/MyDrive/frames/frame_0189.jpg
# /content/drive/MyDrive/frames/frame_0190.jpg
# /content/drive/MyDrive/frames/frame_0191.jpg
# /content/drive/MyDrive/frames/frame_0192.jpg
# /content/drive/MyDrive/frames/frame_0193.jpg
# /content/drive/MyDrive/frames/frame_0194.jpg
# /content/drive/MyDrive/frames/frame_0195.jpg
# /content/drive/MyDrive/frames/frame_0196.jpg
# /content/drive/MyDrive/frames/frame_0197.jpg
# /content/drive/MyDrive/frames/frame_0198.jpg
# /content/drive/MyDrive/frames/frame_0199.jpg
# /content/drive/MyDrive/frames/frame_0200.jpg
# /content/drive/MyDrive/frames/frame_0201.jpg
# /content/drive/MyDrive/frames/frame_0202.jpg
# /content/drive/MyDrive/frames/frame_0203.jpg
# /content/drive/MyDrive/frames/frame_0204.jpg
# /content/drive/MyDrive/frames/frame_0205.jpg
# /content/drive/MyDrive/frames/frame_0206.jpg
# /content/drive/MyDrive/frames/frame_0207.jpg
# /content/drive/MyDrive/frames/frame_0208.jpg
# /content/drive/MyDrive/frames/frame_0209.jpg
# /content/drive/MyDrive/frames/frame_0210.jpg
# /content/drive/MyDrive/frames/frame_0211.jpg
# /content/drive/MyDrive/frames/frame_0212.jpg
# /content/drive/MyDrive/frames/frame_0213.jpg
# /content/drive/MyDrive/frames/frame_0214.jpg
# /content/drive/MyDrive/frames/frame_0215.jpg
# /content/drive/MyDrive/frames/frame_0216.jpg
# /content/drive/MyDrive/frames/frame_0217.jpg
# /content/drive/MyDrive/frames/frame_0218.jpg
# /content/drive/MyDrive/frames/frame_0219.jpg
# /content/drive/MyDrive/frames/frame_0220.jpg
# /content/drive/MyDrive/frames/frame_0221.jpg
# /content/drive/MyDrive/frames/frame_0222.jpg
# /content/drive/MyDrive/frames/frame_0223.jpg
# /content/drive/MyDrive/frames/frame_0224.jpg
# /content/drive/MyDrive/frames/frame_0225.jpg
# /content/drive/MyDrive/frames/frame_0226.jpg
# /content/drive/MyDrive/frames/frame_0227.jpg
# /content/drive/MyDrive/frames/frame_0228.jpg
# /content/drive/MyDrive/frames/frame_0229.jpg
# /content/drive/MyDrive/frames/frame_0230.jpg
# /content/drive/MyDrive/frames/frame_0231.jpg
# /content/drive/MyDrive/frames/frame_0232.jpg
# /content/drive/MyDrive/frames/frame_0233.jpg
# /content/drive/MyDrive/frames/frame_0234.jpg
# /content/drive/MyDrive/frames/frame_0235.jpg
# /content/drive/MyDrive/frames/frame_0236.jpg
# /content/drive/MyDrive/frames/frame_0237.jpg
# /content/drive/MyDrive/frames/frame_0238.jpg
# /content/drive/MyDrive/frames/frame_0239.jpg
# /content/drive/MyDrive/frames/frame_0240.jpg
# /content/drive/MyDrive/frames/frame_0241.jpg
# /content/drive/MyDrive/frames/frame_0242.jpg
# /content/drive/MyDrive/frames/frame_0243.jpg
# /content/drive/MyDrive/frames/frame_0244.jpg
# /content/drive/MyDrive/frames/frame_0245.jpg
# /content/drive/MyDrive/frames/frame_0246.jpg
# /content/drive/MyDrive/frames/frame_0247.jpg
# /content/drive/MyDrive/frames/frame_0248.jpg
# /content/drive/MyDrive/frames/frame_0249.jpg
# /content/drive/MyDrive/frames/frame_0250.jpg
# /content/drive/MyDrive/frames/frame_0251.jpg
# /content/drive/MyDrive/frames/frame_0252.jpg
# /content/drive/MyDrive/frames/frame_0253.jpg
# Extracted 253 frames.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
#@title Setup Super Resolution Model { run: "auto" }
pretrained_model = "real_sr x4" # ["real_sr x4", "classical_sr x2", "classical_sr x3", "classical_sr x4", "classical_sr x8", "lightweight x2", "lightweight x3", "lightweight x4"]

model_type, scale = pretrained_model.split(' ')
scale = int(scale[1])

# initialize super resolution model
sr = SwinIR_SR(model_type, scale)

print(f'Loaded {pretrained_model} successfully')
# Out:
# downloading weights to /content/SwinIR_wrapper/SwinIR_wrapper/weights/003_realSR_BSRGAN_DFO_s64w8_SwinIR-M_x4_GAN.pth
# Loaded real_sr x4 successfully

# %% [markdown]
# ---

# %% [markdown]
# ## Use The Model
#
# > If the image size isn't too big, the image can be fed to the model as it is However, for larger images the GPU will run out of memory. A simple solution is to use the model on smaller patches and then combine the results for a large image.

# %% [markdown]
# ### Directly - `sr.upscale()`

# %%
# show results
    #compare_sr_with_original(img_lq, img_hq)
import cv2
import os
import glob


input_folder='/content/drive/MyDrive/frames'
output_folder = '/content/drive/MyDrive/output/'  # Adjust the folder name if needed

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Process all images in the input folder
frame_files = sorted(glob.glob(os.path.join(input_folder, '*.jpg')))  # Adjust the file extension if needed
 # Adjust the file extension if needed

for frame_file in frame_files:
    # Load the input image
    img_lq = cv2.imread(frame_file, cv2.IMREAD_COLOR)

    # Perform super-resolution
    img_hq = sr.upscale(img_lq)

    # Save the high-quality image to the output folder
    output_filename = os.path.join(output_folder, os.path.basename(frame_file))
    cv2.imwrite(output_filename, img_hq)

# %%
import cv2
import os
import glob

# Path to the folder containing image frames
frame_folder = '/content/drive/MyDrive/output'  # Update with the correct folder path
output_video_path = '/content/drive/MyDrive/reconstructed_video.mp4'  # Path for the output video

# List the image frame files in the folder
frame_files = sorted(glob.glob(os.path.join(frame_folder, '*.jpg')))  # Adjust the file extension if needed

# Check if there are any frames
if not frame_files:
    print("No frames found in the specified folder.")
else:
    # Read the first frame to get frame dimensions
    frame = cv2.imread(frame_files[0])
    frame_height, frame_width, channels = frame.shape

    # Define the codec and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Video codec, change as needed
    output_video = cv2.VideoWriter(output_video_path, fourcc, 30.0, (frame_width, frame_height))

    # Write each frame to the video
    for frame_file in frame_files:
        frame = cv2.imread(frame_file)
        output_video.write(frame)

    # Release the VideoWriter
    output_video.release()

    print(f"Reconstructed video saved to {output_video_path}")
# Out:
# Reconstructed video saved to /content/drive/MyDrive/reconstructed_video.mp4

# %%
# !pip install opencv-python-headless
# !pip install scikit-video
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.23.5)
# Collecting scikit-video
#   Downloading scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from scikit-video) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from scikit-video) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from scikit-video) (1.11.3)
# Installing collected packages: scikit-video
# Successfully installed scikit-video-1.1.11

# %%
from moviepy.editor import VideoFileClip, AudioFileClip


swinir_video = VideoFileClip("/content/drive/MyDrive/reconstructed_video.mp4")
original_audio = AudioFileClip("/content/drive/MyDrive/test.mp4")
video_with_audio = swinir_video.set_audio(original_audio)
video_with_audio.write_videofile("/content/drive/MyDrive/swinir.mp4", codec='libx264')
# Out:
# Moviepy - Building video /content/drive/MyDrive/swinir.mp4.
# MoviePy - Writing audio in swinirTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video /content/drive/MyDrive/swinir.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/swinir.mp4

# %%
#@title # **Metrics**
import cv2
import numpy as np
from skimage.metrics import peak_signal_noise_ratio, structural_similarity


original_video = cv2.VideoCapture("/content/drive/MyDrive/test.mp4")
swinir_output_video = cv2.VideoCapture("/content/drive/MyDrive/swinir.mp4")


fps = original_video.get(cv2.CAP_PROP_FPS)


frame_count = min(
    int(original_video.get(cv2.CAP_PROP_FRAME_COUNT)),
    int(swinir_output_video.get(cv2.CAP_PROP_FRAME_COUNT))
)


psnr_values = []
ssim_values = []


for frame_index in range(frame_count):

    original_frame = original_video.read()[1]
    swinir_frame = swinir_output_video.read()[1]


    if original_frame.shape != swinir_frame.shape:
        swinir_frame = cv2.resize(swinir_frame, (original_frame.shape[1], original_frame.shape[0]))


    psnr = peak_signal_noise_ratio(original_frame, swinir_frame)
    ssim = structural_similarity(original_frame, swinir_frame, multichannel=True)


    psnr_values.append(psnr)
    ssim_values.append(ssim)


average_psnr = sum(psnr_values) / len(psnr_values)
average_ssim = sum(ssim_values) / len(ssim_values)

print(f"Average PSNR: {average_psnr:.2f}")
print(f"Average SSIM: {average_ssim:.2f}")
# Out:
# WARNING:py.warnings:<ipython-input-10-7436e315ebe6>:34: FutureWarning: `multichannel` is a deprecated argument name for `structural_similarity`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   ssim = structural_similarity(original_frame, swinir_frame, multichannel=True)
# Average PSNR: 28.29
# Average SSIM: 0.87
